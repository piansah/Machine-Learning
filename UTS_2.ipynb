# %%
import pandas as pd

# %%
test = pd.read_csv('UTS_test_soal_remedi.csv')
test
# Out:
#           x1        x2        x3        x4        x5        x6        x7  \
# 0   0.622309  0.840328  0.456739  0.583903  0.877817  0.648950  0.308237
# 1   0.104250  0.504839  0.081407  0.541355  0.989223  0.086440  0.742300
# 2   0.333895  0.883909  0.490593  0.790327  0.220103  0.503750  0.680019
# 3   0.249640  0.241752  0.022042  0.419584  0.005163  0.690406  0.285584
# 4   0.756316  0.629541  0.112151  0.369710  0.437547  0.299900  0.980427
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.060387  0.932374  0.223852  0.633527  0.786847  0.454648  0.300652
# 96  0.966816  0.691899  0.817018  0.395999  0.926486  0.448673  0.391005
# 97  0.603083  0.487279  0.290161  0.359799  0.303590  0.904052  0.908608
# 98  0.730995  0.194264  0.598484  0.030587  0.731656  0.111817  0.852571
# 99  0.559804  0.208645  0.171299  0.093035  0.152843  0.301935  0.741689
#
#           x8        x9       x10       x11       x12       x13       x14  \
# 0   0.659289  0.158888  0.844827  0.646738  0.393584  0.130719  0.812627
# 1   0.912791  0.750145  0.948266  0.783214  0.749264  0.441262  0.931630
# 2   0.759122  0.324282  0.615501  0.975490  0.384628  0.103806  0.215870
# 3   0.495526  0.611683  0.437915  0.318608  0.271244  0.651556  0.808505
# 4   0.240323  0.851057  0.031254  0.885291  0.750538  0.413332  0.068493
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.523773  0.913331  0.158196  0.522679  0.646025  0.843936  0.879122
# 96  0.983195  0.341553  0.037151  0.959644  0.583037  0.618189  0.854394
# 97  0.643430  0.469077  0.086630  0.302164  0.053898  0.043106  0.821560
# 98  0.763703  0.232693  0.066910  0.035029  0.488736  0.167057  0.371409
# 99  0.084408  0.827475  0.608449  0.856511  0.411024  0.565229  0.730345
#
#          x15
# 0   0.308979
# 1   0.486826
# 2   0.335376
# 3   0.047226
# 4   0.468962
# ..       ...
# 95  0.897119
# 96  0.016774
# 97  0.373527
# 98  0.819196
# 99  0.604428
#
# [100 rows x 15 columns]

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(80, input_dim=15, activation='relu'))
model.add(Dense(60, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='adam',metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 80)                1280
#
#  dense_11 (Dense)            (None, 60)                4860
#
#  dense_12 (Dense)            (None, 40)                2440
#
#  dense_13 (Dense)            (None, 20)                820
#
#  dense_14 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 9,421
# Trainable params: 9,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.load_weights('uts.h5')

# %%
y_pred = model.predict(test)
# Out:
# 4/4 [==============================] - 1s 4ms/step

# %%
y_pred = y_pred.tolist()
y_pred = [y_pred[i][0] for i in range(len(y_pred))]
y_pred
# Out:
# [2.842841386795044,
#  2.833336114883423,
#  6.569819450378418,
#  -3.385374069213867,
#  8.06527328491211,
#  6.308963298797607,
#  7.305173873901367,
#  8.945249557495117,
#  9.100358009338379,
#  -1.1112059354782104,
#  6.949354648590088,
#  1.3916064500808716,
#  -0.7437466979026794,
#  -3.0267832279205322,
#  2.307615280151367,
#  -1.2060319185256958,
#  2.529402017593384,
#  0.8125039339065552,
#  0.19683530926704407,
#  3.7198641300201416,
#  10.213319778442383,
#  9.020227432250977,
#  2.51017427444458,
#  10.773109436035156,
#  7.123269081115723,
#  4.630366802215576,
#  5.172938823699951,
#  -0.017183244228363037,
#  5.525180339813232,
#  -3.3583881855010986,
#  4.161857604980469,
#  7.05312967300415,
#  7.113686561584473,
#  6.708088397979736,
#  -0.0917416661977768,
#  2.4492239952087402,
#  -0.025740846991539,
#  5.612811088562012,
#  -0.14633925259113312,
#  -0.029901355504989624,
#  0.013181552290916443,
#  1.6551182270050049,
#  5.1162638664245605,
#  5.358500003814697,
#  4.461669921875,
#  -3.510721206665039,
#  6.382601737976074,
#  6.250374794006348,
#  5.386312961578369,
#  0.18069764971733093,
#  8.782620429992676,
#  5.405932903289795,
#  5.1202287673950195,
#  9.780815124511719,
#  2.475490093231201,
#  6.957308769226074,
#  6.85791015625,
#  4.179262638092041,
#  1.8182786703109741,
#  5.071540832519531,
#  6.635466575622559,
#  -0.680867075920105,
#  4.3504319190979,
#  0.49741917848587036,
#  -0.8156242966651917,
#  8.397357940673828,
#  3.4965367317199707,
#  1.318847417831421,
#  0.0024009644985198975,
#  5.080106735229492,
#  10.222769737243652,
#  2.1790661811828613,
#  3.4363059997558594,
#  7.240959644317627,
#  4.094356060028076,
#  2.852778673171997,
#  8.840237617492676,
#  -0.818246066570282,
#  2.6192312240600586,
#  10.447315216064453,
#  4.561399936676025,
#  2.1964428424835205,
#  5.700794219970703,
#  6.245138168334961,
#  9.256263732910156,
#  10.117913246154785,
#  0.3884392976760864,
#  7.929966449737549,
#  -0.31874823570251465,
#  5.85158109664917,
#  3.1663787364959717,
#  1.9665881395339966,
#  10.050202369689941,
#  7.97744083404541,
#  1.1461683511734009,
#  3.074848175048828,
#  0.8684197664260864,
#  3.938246011734009,
#  8.819099426269531,
#  1.8707035779953003]

# %%
hasil_akhir = pd.DataFrame({"y" : y_pred})
hasil_akhir.to_csv("20102007.csv", index = False)
